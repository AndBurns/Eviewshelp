# %%
# -*- coding: utf-8 -*-
"""
Author: Andrew Burns
Created Date: March 2, 2025
Updated Date: March 7, 2025
"""
from pathlib import Path
from lxml import html
from lxml.html.clean import clean_html

dataset = []

# Directory containing the HTML files
directory = Path(r'C:\git\eviewshelp\chm\test')

# Loop through all .html files in the directory
for html_file in directory.glob('*program*.html'):
    with open(html_file, 'r', encoding='utf-8') as file:
        content = file.read()   
    print(f"Read file: {html_file.name}")  # Optional: Display file name
    parsed_html = html.fromstring(content)
# Clean the HTML
    cleaned_html = clean_html(parsed_html)
# Extract text content
    content= cleaned_html.text_content().strip()
#dataset = clean_html(dataset).text_content().strip()
    print(f'Loaded {len(content)} entries')
    dataset+=" "+content
# Out:
# Read file: commandcmd-program.html
# Loaded 868 entries
# Read file: cprogram-Control_of_Execution.html
# Loaded 18072 entries
# Read file: cprogram-EViews_Programming.html
# Loaded 1260 entries
# Read file: cprogram-Multiple_Program_Files.html
# Loaded 3739 entries
# Read file: cprogram-Program_Arguments.html
# Loaded 3135 entries
# Read file: cprogram-Program_Basics.html
# Loaded 19852 entries
# Read file: cprogram-Program_Modes.html
# Loaded 4991 entries
# Read file: cprogram-Program_Options.html
# Loaded 2800 entries
# Read file: cprogram-Program_Variables.html
# Loaded 16199 entries
# Read file: cprogram-References.html
# Loaded 503 entries
# Read file: cprogram-Simple_Programs.html
# Loaded 6312 entries
# Read file: cprogram-Subroutines.html
# Loaded 22955 entries
# Read file: cprogram-User-Defined_Dialogs.html
# Loaded 21704 entries
# Read file: cprogram-Version_4_Compatibility_Notes.html
# Loaded 9857 entries
# Read file: progref-Programming_Language_Summary.html
# Loaded 697 entries
# Read file: progref-Program_Statements.html
# Loaded 1005 entries
# Read file: userobj-User_Object_Programming_Support.html
# Loaded 3619 entries

# %%
#%%Begin program
import ollama

EMBEDDING_MODEL = 'hf.co/CompendiumLabs/bge-base-en-v1.5-gguf'
LANGUAGE_MODEL = 'hf.co/bartowski/Llama-3.2-1B-Instruct-GGUF'

# Each element in the VECTOR_DB will be a tuple (chunk, embedding)
# The embedding is a list of floats, for example: [0.1, 0.04, -0.34, 0.21, ...]
VECTOR_DB = []
#%% routines
def add_chunk_to_database(chunk):
  embedding = ollama.embed(model=EMBEDDING_MODEL, input=chunk)['embeddings'][0]
  VECTOR_DB.append((chunk, embedding))
  
def cosine_similarity(a, b):
  dot_product = sum([x * y for x, y in zip(a, b)])
  norm_a = sum([x ** 2 for x in a]) ** 0.5
  norm_b = sum([x ** 2 for x in b]) ** 0.5
  return dot_product / (norm_a * norm_b)

def retrieve(query, top_n=3):
  query_embedding = ollama.embed(model=EMBEDDING_MODEL, input=query)['embeddings'][0]
  # temporary list to store (chunk, similarity) pairs
  similarities = []
  for chunk, embedding in VECTOR_DB:
    similarity = cosine_similarity(query_embedding, embedding)
    similarities.append((chunk, similarity))
  # sort by similarity in descending order, because higher similarity means more relevant chunks
  similarities.sort(key=lambda x: x[1], reverse=True)
  # finally, return the top N most relevant chunks
  return similarities[:top_n]

# %%
import time

total_chunks = len(dataset)
progress_interval = max(1, total_chunks // 1000)  # Every 0.1% of total chunks
start_time = time.time()

for i, chunk in enumerate(dataset):
    add_chunk_to_database(chunk)
    
    if i % progress_interval == 0 or i == total_chunks - 1:
        elapsed_time = time.time() - start_time
        progress = (i + 1) / total_chunks
        estimated_total_time = elapsed_time / progress if progress > 0 else 0
        time_remaining = estimated_total_time - elapsed_time

        hours, rem = divmod(time_remaining, 3600)
        minutes, seconds = divmod(rem, 60)
        
        print(f'Progress: {progress * 100:.1f}% - {i+1}/{total_chunks} chunks processed')
        print(f'Estimated time remaining: {int(hours):02d}:{int(minutes):02d}:{int(seconds):02d}')
# Out:
# Progress: 0.0% - 1/137585 chunks processed
# Estimated time remaining: 01:19:06
# Progress: 0.1% - 138/137585 chunks processed
# Estimated time remaining: 01:13:36
# Progress: 0.2% - 275/137585 chunks processed
# Estimated time remaining: 01:11:56
# Progress: 0.3% - 412/137585 chunks processed
# Estimated time remaining: 01:10:50
# Progress: 0.4% - 549/137585 chunks processed
# Estimated time remaining: 01:10:28
# Progress: 0.5% - 686/137585 chunks processed
# Estimated time remaining: 01:11:21
# Progress: 0.6% - 823/137585 chunks processed
# Estimated time remaining: 01:11:54
# Progress: 0.7% - 960/137585 chunks processed
# Estimated time remaining: 01:11:53
# Progress: 0.8% - 1097/137585 chunks processed
# Estimated time remaining: 01:11:41
# Progress: 0.9% - 1234/137585 chunks processed
# Estimated time remaining: 01:11:13
# Progress: 1.0% - 1371/137585 chunks processed
# Estimated time remaining: 01:10:54
# Progress: 1.1% - 1508/137585 chunks processed
# Estimated time remaining: 01:10:55
# Progress: 1.2% - 1645/137585 chunks processed
# Estimated time remaining: 01:10:43
# Progress: 1.3% - 1782/137585 chunks processed
# Estimated time remaining: 01:10:48
# Progress: 1.4% - 1919/137585 chunks processed
# Estimated time remaining: 01:10:37
# Progress: 1.5% - 2056/137585 chunks processed
# Estimated time remaining: 01:10:28
# Progress: 1.6% - 2193/137585 chunks processed
# Estimated time remaining: 01:10:19
# Progress: 1.7% - 2330/137585 chunks processed
# Estimated time remaining: 01:10:18
# Progress: 1.8% - 2467/137585 chunks processed
# Estimated time remaining: 01:10:03
# Progress: 1.9% - 2604/137585 chunks processed
# Estimated time remaining: 01:10:07
# Progress: 2.0% - 2741/137585 chunks processed
# Estimated time remaining: 01:10:10
# Progress: 2.1% - 2878/137585 chunks processed
# Estimated time remaining: 01:10:00
# Progress: 2.2% - 3015/137585 chunks processed
# Estimated time remaining: 01:09:46
# Progress: 2.3% - 3152/137585 chunks processed
# Estimated time remaining: 01:09:38
# Progress: 2.4% - 3289/137585 chunks processed
# Estimated time remaining: 01:09:32
# Progress: 2.5% - 3426/137585 chunks processed
# Estimated time remaining: 01:09:26
# Progress: 2.6% - 3563/137585 chunks processed
# Estimated time remaining: 01:09:20
# Progress: 2.7% - 3700/137585 chunks processed
# Estimated time remaining: 01:09:21
# Progress: 2.8% - 3837/137585 chunks processed
# Estimated time remaining: 01:09:20
# Progress: 2.9% - 3974/137585 chunks processed
# Estimated time remaining: 01:09:08
# Progress: 3.0% - 4111/137585 chunks processed
# Estimated time remaining: 00:01:49
# Progress: 97.6% - 134261/137585 chunks processed
# Estimated time remaining: 00:01:44
# Progress: 97.7% - 134398/137585 chunks processed
# Estimated time remaining: 00:01:40
# Progress: 97.8% - 134535/137585 chunks processed
# Estimated time remaining: 00:01:36
# Progress: 97.9% - 134672/137585 chunks processed
# Estimated time remaining: 00:01:32
# Progress: 98.0% - 134809/137585 chunks processed
# Estimated time remaining: 00:01:27
# Progress: 98.1% - 134946/137585 chunks processed
# Estimated time remaining: 00:01:23
# Progress: 98.2% - 135083/137585 chunks processed
# Estimated time remaining: 00:01:19
# Progress: 98.3% - 135220/137585 chunks processed
# Estimated time remaining: 00:01:14
# Progress: 98.4% - 135357/137585 chunks processed
# Estimated time remaining: 00:01:10
# Progress: 98.5% - 135494/137585 chunks processed
# Estimated time remaining: 00:01:06
# Progress: 98.6% - 135631/137585 chunks processed
# Estimated time remaining: 00:01:01
# Progress: 98.7% - 135768/137585 chunks processed
# Estimated time remaining: 00:00:57
# Progress: 98.8% - 135905/137585 chunks processed
# Estimated time remaining: 00:00:53
# Progress: 98.9% - 136042/137585 chunks processed
# Estimated time remaining: 00:00:48
# Progress: 99.0% - 136179/137585 chunks processed
# Estimated time remaining: 00:00:44
# Progress: 99.1% - 136316/137585 chunks processed
# Estimated time remaining: 00:00:40
# Progress: 99.2% - 136453/137585 chunks processed
# Estimated time remaining: 00:00:35
# Progress: 99.3% - 136590/137585 chunks processed
# Estimated time remaining: 00:00:31
# Progress: 99.4% - 136727/137585 chunks processed
# Estimated time remaining: 00:00:27
# Progress: 99.5% - 136864/137585 chunks processed
# Estimated time remaining: 00:00:22
# Progress: 99.6% - 137001/137585 chunks processed
# Estimated time remaining: 00:00:18
# Progress: 99.7% - 137138/137585 chunks processed
# Estimated time remaining: 00:00:14
# Progress: 99.8% - 137275/137585 chunks processed
# Estimated time remaining: 00:00:09
# Progress: 99.9% - 137412/137585 chunks processed
# Estimated time remaining: 00:00:05
# Progress: 100.0% - 137549/137585 chunks processed
# Estimated time remaining: 00:00:01
# Progress: 100.0% - 137585/137585 chunks processed
# Estimated time remaining: 00:00:00

# %%
#%% process data
#for i, chunk in enumerate(dataset):
##  add_chunk_to_database(chunk)
#  print(f'Added chunk {i+1}/{len(dataset)} to the database')
# Out:
# Added chunk 1/137585 to the database
# Added chunk 2/137585 to the database
# Added chunk 3/137585 to the database
# Added chunk 4/137585 to the database
# Added chunk 5/137585 to the database
# Added chunk 6/137585 to the database
# Added chunk 7/137585 to the database
# Added chunk 8/137585 to the database
# Added chunk 9/137585 to the database
# Added chunk 10/137585 to the database
# Added chunk 11/137585 to the database
# Added chunk 12/137585 to the database
# Added chunk 13/137585 to the database
# Added chunk 14/137585 to the database
# Added chunk 15/137585 to the database
# Added chunk 16/137585 to the database
# Added chunk 17/137585 to the database
# Added chunk 18/137585 to the database
# Added chunk 19/137585 to the database
# Added chunk 20/137585 to the database
# Added chunk 21/137585 to the database
# Added chunk 22/137585 to the database
# Added chunk 23/137585 to the database
# Added chunk 24/137585 to the database
# Added chunk 25/137585 to the database
# Added chunk 26/137585 to the database
# Added chunk 27/137585 to the database
# Added chunk 28/137585 to the database
# Added chunk 29/137585 to the database
# Added chunk 30/137585 to the database
# Added chunk 31/137585 to the database
# Added chunk 32/137585 to the database
# Added chunk 33/137585 to the database
# Added chunk 34/137585 to the database
# Added chunk 35/137585 to the database
# Added chunk 36/137585 to the database
# Added chunk 37/137585 to the database
# Added chunk 38/137585 to the database
# Added chunk 39/137585 to the database
# Added chunk 40/137585 to the database
# Added chunk 41/137585 to the database
# Added chunk 42/137585 to the database
# Added chunk 43/137585 to the database
# Added chunk 44/137585 to the database
# Added chunk 45/137585 to the database
# Added chunk 46/137585 to the database
# Added chunk 47/137585 to the database
# Added chunk 48/137585 to the database
# Added chunk 49/137585 to the database
# Added chunk 50/137585 to the database
# Added chunk 51/137585 to the database
# Added chunk 52/137585 to the database
# Added chunk 53/137585 to the database
# Added chunk 54/137585 to the database
# Added chunk 55/137585 to the database
# Added chunk 56/137585 to the database
# Added chunk 57/137585 to the database
# Added chunk 58/137585 to the database
# Added chunk 59/137585 to the database
# Added chunk 60/137585 to the database
# Added chunk 61/137585 to the database
# Added chunk 62/137585 to the database
# Added chunk 63/137585 to the database
# Added chunk 64/137585 to the database
# Added chunk 65/137585 to the database
# Added chunk 66/137585 to the database
# Added chunk 67/137585 to the database
# Added chunk 68/137585 to the database
# Added chunk 69/137585 to the database
# Added chunk 70/137585 to the database
# Added chunk 71/137585 to the database
# Added chunk 72/137585 to the database
# Added chunk 73/137585 to the database
# Added chunk 74/137585 to the database
# Added chunk 75/137585 to the database
# Added chunk 76/137585 to the database
# Added chunk 77/137585 to the database
# Added chunk 78/137585 to the database
# Added chunk 79/137585 to the database
# Added chunk 80/137585 to the database
# Added chunk 81/137585 to the database
# Added chunk 82/137585 to the database
# Added chunk 83/137585 to the database
# Added chunk 84/137585 to the database
# Added chunk 85/137585 to the database
# Added chunk 86/137585 to the database
# Added chunk 87/137585 to the database
# Added chunk 88/137585 to the database
# Added chunk 89/137585 to the database
# Added chunk 90/137585 to the database
# Added chunk 91/137585 to the database
# Added chunk 92/137585 to the database
# Added chunk 93/137585 to the database
# Added chunk 94/137585 to the database
# Added chunk 95/137585 to the database
# Added chunk 96/137585 to the database
# Added chunk 97/137585 to the database
# Added chunk 98/137585 to the database
# Added chunk 99/137585 to the database
# Added chunk 100/137585 to the database
# Added chunk 101/137585 to the database
# Added chunk 102/137585 to the database
# Added chunk 103/137585 to the database
# Added chunk 104/137585 to the database
# Added chunk 105/137585 to the database
# Added chunk 106/137585 to the database
# Added chunk 107/137585 to the database
# Added chunk 108/137585 to the database
# Added chunk 109/137585 to the database
# Added chunk 110/137585 to the database
# Added chunk 111/137585 to the database
# Added chunk 112/137585 to the database
# Added chunk 113/137585 to the database
# Added chunk 114/137585 to the database
# Added chunk 115/137585 to the database
# Added chunk 116/137585 to the database
# Added chunk 117/137585 to the database
# Added chunk 118/137585 to the database
# Added chunk 119/137585 to the database
# Added chunk 120/137585 to the database
# Added chunk 121/137585 to the database
# Added chunk 122/137585 to the database
# Added chunk 123/137585 to the database
# Added chunk 124/137585 to the database
# Added chunk 125/137585 to the database
# Added chunk 126/137585 to the database
# Added chunk 127/137585 to the database
# Added chunk 128/137585 to the database
# Added chunk 129/137585 to the database
# Added chunk 130/137585 to the database
# Added chunk 131/137585 to the database
# Added chunk 132/137585 to the database
# Added chunk 133/137585 to the database
# Added chunk 134/137585 to the database
# Added chunk 135/137585 to the database
# Added chunk 136/137585 to the database
# Added chunk 137/137585 to the database
# Added chunk 138/137585 to the database
# Added chunk 139/137585 to the database
# Added chunk 140/137585 to the database
# Added chunk 141/137585 to the database
# Added chunk 142/137585 to the database
# Added chunk 143/137585 to the database
# Added chunk 144/137585 to the database
# Added chunk 145/137585 to the database
# Added chunk 146/137585 to the database
# Added chunk 147/137585 to the database
# Added chunk 148/137585 to the database
# Added chunk 149/137585 to the database
# Added chunk 150/137585 to the database
# Added chunk 151/137585 to the database
# Added chunk 152/137585 to the database
# Added chunk 153/137585 to the database
# Added chunk 154/137585 to the database
# Added chunk 155/137585 to the database
# Added chunk 156/137585 to the database
# Added chunk 157/137585 to the database
# Added chunk 158/137585 to the database
# Added chunk 159/137585 to the database
# Added chunk 160/137585 to the database
# Added chunk 161/137585 to the database
# Added chunk 162/137585 to the database
# Added chunk 163/137585 to the database
# Added chunk 164/137585 to the database
# Added chunk 165/137585 to the database
# Added chunk 166/137585 to the database
# Added chunk 167/137585 to the database
# Added chunk 168/137585 to the database
# Added chunk 169/137585 to the database
# Added chunk 170/137585 to the database
# Added chunk 171/137585 to the database
# Added chunk 172/137585 to the database
# Added chunk 173/137585 to the database
# Added chunk 174/137585 to the database
# Added chunk 175/137585 to the database
# Added chunk 176/137585 to the database
# Added chunk 177/137585 to the database
# Added chunk 178/137585 to the database
# Added chunk 179/137585 to the database
# Added chunk 180/137585 to the database
# Added chunk 181/137585 to the database
# Added chunk 182/137585 to the database
# Added chunk 183/137585 to the database
# Added chunk 184/137585 to the database
# Added chunk 185/137585 to the database
# Added chunk 186/137585 to the database
# Added chunk 187/137585 to the database
# Added chunk 188/137585 to the database
# Added chunk 189/137585 to the database
# Added chunk 190/137585 to the database
# Added chunk 191/137585 to the database
# Added chunk 192/137585 to the database
# Added chunk 193/137585 to the database
# Added chunk 194/137585 to the database
# Added chunk 195/137585 to the database
# Added chunk 196/137585 to the database
# Added chunk 197/137585 to the database
# Added chunk 198/137585 to the database
# Added chunk 199/137585 to the database
# Added chunk 200/137585 to the database
# Added chunk 201/137585 to the database
# Added chunk 202/137585 to the database
# Added chunk 203/137585 to the database
# Added chunk 204/137585 to the database
# Added chunk 205/137585 to the database
# Added chunk 206/137585 to the database
# Added chunk 207/137585 to the database
# Added chunk 208/137585 to the database
# Added chunk 209/137585 to the database
# Added chunk 210/137585 to the database
# Added chunk 211/137585 to the database
# Added chunk 212/137585 to the database
# Added chunk 213/137585 to the database
# Added chunk 214/137585 to the database
# Added chunk 215/137585 to the database
# Added chunk 216/137585 to the database
# Added chunk 217/137585 to the database
# Added chunk 218/137585 to the database
# Added chunk 219/137585 to the database
# Added chunk 220/137585 to the database
# Added chunk 221/137585 to the database
# Added chunk 222/137585 to the database
# Added chunk 223/137585 to the database
# Added chunk 224/137585 to the database
# Added chunk 225/137585 to the database
# Added chunk 226/137585 to the database
# Added chunk 227/137585 to the database
# Added chunk 228/137585 to the database
# Added chunk 229/137585 to the database
# Added chunk 230/137585 to the database
# Added chunk 231/137585 to the database
# Added chunk 232/137585 to the database
# Added chunk 233/137585 to the database
# Added chunk 234/137585 to the database
# Added chunk 235/137585 to the database
# Added chunk 236/137585 to the database
# Added chunk 237/137585 to the database
# Added chunk 238/137585 to the database
# Added chunk 239/137585 to the database
# Added chunk 240/137585 to the database
# Added chunk 241/137585 to the database
# Added chunk 242/137585 to the database
# Added chunk 243/137585 to the database
# Added chunk 244/137585 to the database
# Added chunk 245/137585 to the database
# Added chunk 246/137585 to the database
# Added chunk 247/137585 to the database
# Added chunk 248/137585 to the database
# Added chunk 249/137585 to the database
# Added chunk 250/137585 to the database
# Added chunk 251/137585 to the database
# Added chunk 252/137585 to the database
# Added chunk 253/137585 to the database
# Added chunk 254/137585 to the database
# Added chunk 255/137585 to the database
# Added chunk 256/137585 to the database
# Added chunk 257/137585 to the database
# Added chunk 258/137585 to the database
# Added chunk 259/137585 to the database
# Added chunk 260/137585 to the database
# Added chunk 261/137585 to the database
# Added chunk 262/137585 to the database
# Added chunk 263/137585 to the database
# Added chunk 264/137585 to the database
# Added chunk 265/137585 to the database
# Added chunk 266/137585 to the database
# Added chunk 267/137585 to the database
# Added chunk 268/137585 to the database
# Added chunk 269/137585 to the database
# Added chunk 270/137585 to the database
# Added chunk 271/137585 to the database
# Added chunk 272/137585 to the database
# Added chunk 273/137585 to the database
# Added chunk 274/137585 to the database
# Added chunk 275/137585 to the database
# Added chunk 276/137585 to the database
# Added chunk 277/137585 to the database
# Added chunk 278/137585 to the database
# Added chunk 279/137585 to the database
# Added chunk 280/137585 to the database
# Added chunk 281/137585 to the database
# Added chunk 282/137585 to the database
# Added chunk 283/137585 to the database
# Added chunk 284/137585 to the database
# Added chunk 285/137585 to the database
# Added chunk 286/137585 to the database
# Added chunk 287/137585 to the database
# Added chunk 288/137585 to the database
# Added chunk 289/137585 to the database
# Added chunk 290/137585 to the database
# Added chunk 291/137585 to the database
# Added chunk 292/137585 to the database
# Added chunk 293/137585 to the database
# Added chunk 294/137585 to the database
# Added chunk 295/137585 to the database
# Added chunk 296/137585 to the database
# Added chunk 297/137585 to the database
# Added chunk 298/137585 to the database
# Added chunk 299/137585 to the database
# Added chunk 300/137585 to the database
# Added chunk 301/137585 to the database
# Added chunk 302/137585 to the database
# Added chunk 303/137585 to the database
# Added chunk 304/137585 to the database
# Added chunk 305/137585 to the database
# Added chunk 306/137585 to the database
# Added chunk 307/137585 to the database
# Added chunk 308/137585 to the database
# Added chunk 309/137585 to the database
# Added chunk 310/137585 to the database
# Added chunk 311/137585 to the database
# Added chunk 312/137585 to the database
# Added chunk 313/137585 to the database
# Added chunk 314/137585 to the database
# Added chunk 315/137585 to the database
# Added chunk 316/137585 to the database
# Added chunk 317/137585 to the database
# Added chunk 318/137585 to the database
# Added chunk 319/137585 to the database
# Added chunk 320/137585 to the database
# Added chunk 321/137585 to the database
# Added chunk 322/137585 to the database
# Added chunk 323/137585 to the database
# Added chunk 324/137585 to the database
# Added chunk 325/137585 to the database
# Added chunk 326/137585 to the database
# Added chunk 327/137585 to the database
# Added chunk 328/137585 to the database
# Added chunk 329/137585 to the database
# Added chunk 330/137585 to the database
# Added chunk 331/137585 to the database
# Added chunk 332/137585 to the database
# Added chunk 333/137585 to the database
# Added chunk 334/137585 to the database
# Added chunk 335/137585 to the database
# Added chunk 336/137585 to the database
# Added chunk 337/137585 to the database
# Added chunk 338/137585 to the database
# Added chunk 339/137585 to the database
# Added chunk 340/137585 to the database
# Added chunk 341/137585 to the database
# Added chunk 342/137585 to the database
# Added chunk 343/137585 to the database
# Added chunk 344/137585 to the database
# Added chunk 345/137585 to the database
# Added chunk 346/137585 to the database
# Added chunk 347/137585 to the database
# Added chunk 348/137585 to the database
# Added chunk 349/137585 to the database
# Added chunk 350/137585 to the database
# Added chunk 351/137585 to the database
# Added chunk 352/137585 to the database
# Added chunk 353/137585 to the database
# Added chunk 354/137585 to the database
# Added chunk 355/137585 to the database
# Added chunk 356/137585 to the database
# Added chunk 357/137585 to the database
# Added chunk 358/137585 to the database
# Added chunk 359/137585 to the database
# Added chunk 360/137585 to the database
# Added chunk 361/137585 to the database
# Added chunk 362/137585 to the database
# Added chunk 363/137585 to the database
# Added chunk 364/137585 to the database
# Added chunk 365/137585 to the database
# Added chunk 366/137585 to the database
# Added chunk 367/137585 to the database
# Added chunk 368/137585 to the database
# Added chunk 369/137585 to the database
# Added chunk 370/137585 to the database
# Added chunk 371/137585 to the database
# Added chunk 372/137585 to the database
# Added chunk 373/137585 to the database
# Added chunk 374/137585 to the database
# Added chunk 375/137585 to the database
# Added chunk 376/137585 to the database
# Added chunk 377/137585 to the database
# Added chunk 378/137585 to the database
# Added chunk 379/137585 to the database
# Added chunk 380/137585 to the database
# Added chunk 381/137585 to the database
# Added chunk 382/137585 to the database
# Added chunk 383/137585 to the database
# Added chunk 384/137585 to the database
# Added chunk 385/137585 to the database
# Added chunk 386/137585 to the database
# Added chunk 387/137585 to the database
# Added chunk 388/137585 to the database
# Added chunk 389/137585 to the database
# Added chunk 390/137585 to the database
# Added chunk 391/137585 to the database
# Added chunk 392/137585 to the database
# Added chunk 393/137585 to the database
# Added chunk 394/137585 to the database
# Added chunk 395/137585 to the database
# Added chunk 396/137585 to the database
# Added chunk 397/137585 to the database
# Added chunk 398/137585 to the database
# Added chunk 399/137585 to the database
# Added chunk 400/137585 to the database
# Added chunk 401/137585 to the database
# Added chunk 402/137585 to the database
# Added chunk 403/137585 to the database
# Added chunk 404/137585 to the database
# Added chunk 405/137585 to the database
# Added chunk 406/137585 to the database
# Added chunk 407/137585 to the database
# Added chunk 408/137585 to the database
# Added chunk 409/137585 to the database
# Added chunk 410/137585 to the database
# Added chunk 411/137585 to the database
# Added chunk 412/137585 to the database
# Added chunk 413/137585 to the database
# Added chunk 414/137585 to the database
# Added chunk 415/137585 to the database
# Added chunk 416/137585 to the database
# Added chunk 417/137585 to the database
# Added chunk 418/137585 to the database
# Added chunk 419/137585 to the database
# Added chunk 420/137585 to the database
# Added chunk 421/137585 to the database
# Added chunk 422/137585 to the database
# Added chunk 423/137585 to the database
# Added chunk 424/137585 to the database
# Added chunk 425/137585 to the database
# Added chunk 426/137585 to the database
# Added chunk 427/137585 to the database
# Added chunk 428/137585 to the database
# Added chunk 429/137585 to the database
# Added chunk 430/137585 to the database
# Added chunk 431/137585 to the database
# Added chunk 432/137585 to the database
# Added chunk 433/137585 to the database
# Added chunk 434/137585 to the database
# Added chunk 435/137585 to the database
# Added chunk 436/137585 to the database
# Added chunk 437/137585 to the database
# Added chunk 438/137585 to the database
# Added chunk 439/137585 to the database
# Added chunk 440/137585 to the database
# Added chunk 441/137585 to the database
# Added chunk 442/137585 to the database
# Added chunk 443/137585 to the database
# Added chunk 444/137585 to the database
# Added chunk 445/137585 to the database
# Added chunk 446/137585 to the database
# Added chunk 447/137585 to the database
# Added chunk 448/137585 to the database
# Added chunk 449/137585 to the database
# Added chunk 450/137585 to the database
# Added chunk 451/137585 to the database
# Added chunk 452/137585 to the database
# Added chunk 453/137585 to the database
# Added chunk 454/137585 to the database
# Added chunk 455/137585 to the database
# Added chunk 456/137585 to the database
# Added chunk 457/137585 to the database
# Added chunk 458/137585 to the database
# Added chunk 459/137585 to the database
# Added chunk 460/137585 to the database
# Added chunk 461/137585 to the database
# Added chunk 462/137585 to the database
# Added chunk 463/137585 to the database
# Added chunk 464/137585 to the database
# Added chunk 465/137585 to the database
# Added chunk 466/137585 to the database
# Added chunk 467/137585 to the database
# Added chunk 468/137585 to the database
# Added chunk 469/137585 to the database
# Added chunk 470/137585 to the database
# Added chunk 471/137585 to the database
# Added chunk 472/137585 to the database
# Added chunk 473/137585 to the database
# Added chunk 474/137585 to the database
# Added chunk 475/137585 to the database
# Added chunk 476/137585 to the database
# Added chunk 477/137585 to the database
# Added chunk 478/137585 to the database
# Added chunk 479/137585 to the database
# Added chunk 480/137585 to the database
# Added chunk 481/137585 to the database
# Added chunk 482/137585 to the database
# Added chunk 483/137585 to the database
# Added chunk 484/137585 to the database
# Added chunk 485/137585 to the database
# Added chunk 486/137585 to the database
# Added chunk 487/137585 to the database
# Added chunk 488/137585 to the database
# Added chunk 489/137585 to the database
# Added chunk 490/137585 to the database
# Added chunk 491/137585 to the database
# Added chunk 492/137585 to the database
# Added chunk 493/137585 to the database
# Added chunk 494/137585 to the database
# Added chunk 495/137585 to the database
# Added chunk 496/137585 to the database
# Added chunk 497/137585 to the database
# Added chunk 498/137585 to the database
# Added chunk 499/137585 to the database
# Added chunk 500/137585 to the database
# Added chunk 501/137585 to the database
# Added chunk 502/137585 to the database
# Added chunk 503/137585 to the database
# Added chunk 504/137585 to the database
# Added chunk 505/137585 to the database
# Added chunk 506/137585 to the database
# Added chunk 507/137585 to the database
# Added chunk 508/137585 to the database
# Added chunk 509/137585 to the database
# Added chunk 510/137585 to the database
# Added chunk 511/137585 to the database
# Added chunk 512/137585 to the database
# Added chunk 513/137585 to the database
# Added chunk 514/137585 to the database
# Added chunk 515/137585 to the database
# Added chunk 516/137585 to the database
# Added chunk 517/137585 to the database
# Added chunk 518/137585 to the database
# Added chunk 519/137585 to the database
# Added chunk 520/137585 to the database
# Added chunk 521/137585 to the database
# Added chunk 522/137585 to the database
# Added chunk 523/137585 to the database
# Added chunk 524/137585 to the database
# Added chunk 525/137585 to the database
# Added chunk 526/137585 to the database
# Added chunk 527/137585 to the database
# Added chunk 528/137585 to the database
# Added chunk 529/137585 to the database
# Added chunk 530/137585 to the database
# Added chunk 531/137585 to the database
# Added chunk 532/137585 to the database
# Added chunk 533/137585 to the database
# Added chunk 534/137585 to the database
# Added chunk 535/137585 to the database
# Added chunk 536/137585 to the database
# Added chunk 537/137585 to the database
# Added chunk 538/137585 to the database
# Added chunk 539/137585 to the database
# Added chunk 540/137585 to the database
# Added chunk 541/137585 to the database
# Added chunk 542/137585 to the database
# Added chunk 543/137585 to the database
# Added chunk 544/137585 to the database
# Added chunk 545/137585 to the database
# Added chunk 546/137585 to the database
# Added chunk 547/137585 to the database
# Added chunk 548/137585 to the database
# Added chunk 549/137585 to the database
# Added chunk 550/137585 to the database
# Added chunk 551/137585 to the database
# Added chunk 552/137585 to the database
# Added chunk 553/137585 to the database
# Added chunk 554/137585 to the database
# Added chunk 555/137585 to the database
# Added chunk 556/137585 to the database
# Added chunk 557/137585 to the database
# Added chunk 558/137585 to the database
# Added chunk 559/137585 to the database
# Added chunk 560/137585 to the database
# Added chunk 561/137585 to the database
# Added chunk 562/137585 to the database
# Added chunk 563/137585 to the database
# Added chunk 564/137585 to the database
# Added chunk 565/137585 to the database
# Added chunk 566/137585 to the database
# Added chunk 567/137585 to the database
# Added chunk 568/137585 to the database
# Added chunk 569/137585 to the database
# Added chunk 570/137585 to the database
# Added chunk 571/137585 to the database
# Added chunk 572/137585 to the database
# Added chunk 573/137585 to the database
# Added chunk 574/137585 to the database
# Added chunk 575/137585 to the database
# Added chunk 576/137585 to the database
# Added chunk 577/137585 to the database
# Added chunk 578/137585 to the database
# Added chunk 579/137585 to the database
# Added chunk 580/137585 to the database
# Added chunk 581/137585 to the database
# Added chunk 582/137585 to the database
# Added chunk 583/137585 to the database
# Added chunk 584/137585 to the database
# Added chunk 585/137585 to the database
# Added chunk 586/137585 to the database
# Added chunk 587/137585 to the database
# Added chunk 588/137585 to the database
# Added chunk 589/137585 to the database
# Added chunk 590/137585 to the database
# Added chunk 591/137585 to the database
# Added chunk 592/137585 to the database
# Added chunk 593/137585 to the database
# Added chunk 594/137585 to the database
# Added chunk 595/137585 to the database
# Added chunk 596/137585 to the database
# Added chunk 597/137585 to the database
# Added chunk 598/137585 to the database
# Added chunk 599/137585 to the database
# Added chunk 600/137585 to the database
# Added chunk 601/137585 to the database
# Added chunk 602/137585 to the database
# Added chunk 603/137585 to the database
# Added chunk 604/137585 to the database
# Added chunk 605/137585 to the database
# Added chunk 606/137585 to the database
# Added chunk 607/137585 to the database
# Added chunk 608/137585 to the database
# Added chunk 609/137585 to the database
# Added chunk 610/137585 to the database
# Added chunk 611/137585 to the database
# Added chunk 612/137585 to the database
# Added chunk 613/137585 to the database
# Added chunk 614/137585 to the database
# Added chunk 615/137585 to the database
# Added chunk 616/137585 to the database
# Added chunk 617/137585 to the database
# Added chunk 618/137585 to the database
# Added chunk 619/137585 to the database
# Added chunk 620/137585 to the database
# Added chunk 621/137585 to the database
# Added chunk 622/137585 to the database
# Added chunk 623/137585 to the database
# Added chunk 624/137585 to the database
# Added chunk 625/137585 to the database
# Added chunk 626/137585 to the database
# Added chunk 627/137585 to the database
# Added chunk 628/137585 to the database
# Added chunk 629/137585 to the database
# Added chunk 630/137585 to the database
# Added chunk 631/137585 to the database
# Added chunk 632/137585 to the database
# Added chunk 633/137585 to the database
# Added chunk 634/137585 to the database
# Added chunk 635/137585 to the database
# Added chunk 636/137585 to the database
# Added chunk 637/137585 to the database
# Added chunk 638/137585 to the database
# Added chunk 639/137585 to the database
# Added chunk 640/137585 to the database
# Added chunk 641/137585 to the database
# Added chunk 642/137585 to the database
# Added chunk 643/137585 to the database
# Added chunk 644/137585 to the database
# Added chunk 645/137585 to the database
# Added chunk 646/137585 to the database
# Added chunk 647/137585 to the database
# Added chunk 648/137585 to the database
# Added chunk 649/137585 to the database
# Added chunk 650/137585 to the database
# Added chunk 651/137585 to the database
# Added chunk 652/137585 to the database
# Added chunk 653/137585 to the database
# Added chunk 654/137585 to the database
# Added chunk 655/137585 to the database
# Added chunk 656/137585 to the database
# Added chunk 657/137585 to the database
# Added chunk 658/137585 to the database
# Added chunk 659/137585 to the database
# Added chunk 660/137585 to the database
# Added chunk 661/137585 to the database
# Added chunk 662/137585 to the database
# Added chunk 663/137585 to the database
# Added chunk 664/137585 to the database
# Added chunk 665/137585 to the database
# Added chunk 666/137585 to the database
# Added chunk 667/137585 to the database
# Added chunk 668/137585 to the database
# Added chunk 669/137585 to the database
# Added chunk 670/137585 to the database
# Added chunk 671/137585 to the database
# Added chunk 672/137585 to the database
# Added chunk 673/137585 to the database
# Added chunk 674/137585 to the database
# Added chunk 675/137585 to the database
# Added chunk 676/137585 to the database
# Added chunk 677/137585 to the database
# Added chunk 678/137585 to the database
# Added chunk 679/137585 to the database
# Added chunk 680/137585 to the database
# Added chunk 681/137585 to the database
# Added chunk 682/137585 to the database
# Added chunk 683/137585 to the database
# Added chunk 684/137585 to the database
# Added chunk 685/137585 to the database
# Added chunk 686/137585 to the database
# Added chunk 687/137585 to the database
# Added chunk 688/137585 to the database
# Added chunk 689/137585 to the database
# Added chunk 690/137585 to the database
# Added chunk 691/137585 to the database
# Added chunk 692/137585 to the database
# Added chunk 693/137585 to the database
# Added chunk 694/137585 to the database
# Added chunk 695/137585 to the database
# Added chunk 696/137585 to the database
# Added chunk 697/137585 to the database
# Added chunk 698/137585 to the database
# Added chunk 699/137585 to the database
# Added chunk 700/137585 to the database
# Added chunk 701/137585 to the database
# Added chunk 702/137585 to the database
# Added chunk 703/137585 to the database
# Added chunk 704/137585 to the database
# Added chunk 705/137585 to the database
# Added chunk 706/137585 to the database
# Added chunk 707/137585 to the database
# Added chunk 708/137585 to the database
# Added chunk 709/137585 to the database
# Added chunk 710/137585 to the database
# Added chunk 711/137585 to the database
# Added chunk 712/137585 to the database
# Added chunk 713/137585 to the database
# Added chunk 714/137585 to the database
# Added chunk 715/137585 to the database
# Added chunk 716/137585 to the database
# Added chunk 717/137585 to the database
# Added chunk 718/137585 to the database
# Added chunk 719/137585 to the database
# Added chunk 720/137585 to the database
# Added chunk 721/137585 to the database
# Added chunk 722/137585 to the database
# Added chunk 723/137585 to the database
# Added chunk 724/137585 to the database
# Added chunk 725/137585 to the database
# Added chunk 726/137585 to the database
# Added chunk 727/137585 to the database
# Added chunk 728/137585 to the database
# Added chunk 729/137585 to the database
# Added chunk 730/137585 to the database
# Added chunk 731/137585 to the database
# Added chunk 732/137585 to the database
# Added chunk 733/137585 to the database
# Added chunk 734/137585 to the database
# Added chunk 735/137585 to the database
# Added chunk 736/137585 to the database
# Added chunk 737/137585 to the database
# Added chunk 738/137585 to the database
# Added chunk 739/137585 to the database
# Added chunk 740/137585 to the database
# Added chunk 741/137585 to the database
# Added chunk 742/137585 to the database
# Added chunk 743/137585 to the database
# Added chunk 744/137585 to the database
# Added chunk 745/137585 to the database
# Added chunk 746/137585 to the database
# Added chunk 747/137585 to the database
# Added chunk 748/137585 to the database
# Added chunk 749/137585 to the database
# Added chunk 750/137585 to the database
# Added chunk 751/137585 to the database
# Added chunk 752/137585 to the database
# Added chunk 753/137585 to the database
# Added chunk 754/137585 to the database
# Added chunk 755/137585 to the database
# Added chunk 756/137585 to the database
# Added chunk 757/137585 to the database
# Added chunk 758/137585 to the database
# Added chunk 759/137585 to the database
# Added chunk 760/137585 to the database
# Added chunk 761/137585 to the database
# Added chunk 762/137585 to the database
# Added chunk 763/137585 to the database
# Added chunk 764/137585 to the database
# Added chunk 765/137585 to the database
# Added chunk 766/137585 to the database
# Added chunk 767/137585 to the database
# Added chunk 768/137585 to the database
# Added chunk 769/137585 to the database
# Added chunk 770/137585 to the database
# Added chunk 771/137585 to the database
# Added chunk 772/137585 to the database
# Added chunk 773/137585 to the database
# Added chunk 774/137585 to the database
# Added chunk 775/137585 to the database
# Added chunk 776/137585 to the database
# Added chunk 777/137585 to the database
# Added chunk 778/137585 to the database
# Added chunk 779/137585 to the database
# Added chunk 780/137585 to the database
# Added chunk 781/137585 to the database
# Added chunk 782/137585 to the database
# Added chunk 783/137585 to the database
# Added chunk 784/137585 to the database
# Added chunk 785/137585 to the database
# Added chunk 786/137585 to the database
# Added chunk 787/137585 to the database
# Added chunk 788/137585 to the database
# Added chunk 789/137585 to the database
# Added chunk 790/137585 to the database
# Added chunk 791/137585 to the database
# Added chunk 792/137585 to the database
# Added chunk 793/137585 to the database
# Added chunk 794/137585 to the database
# Added chunk 795/137585 to the database
# Added chunk 796/137585 to the database
# Added chunk 797/137585 to the database
# Added chunk 798/137585 to the database
# Added chunk 799/137585 to the database
# Added chunk 800/137585 to the database
# Added chunk 801/137585 to the database
# Added chunk 802/137585 to the database
# Added chunk 803/137585 to the database
# Added chunk 804/137585 to the database
# Added chunk 805/137585 to the database
# Added chunk 806/137585 to the database
# Added chunk 807/137585 to the database
# Added chunk 808/137585 to the database
# Added chunk 809/137585 to the database
# Added chunk 810/137585 to the database
# Added chunk 811/137585 to the database
# Added chunk 812/137585 to the database
# Added chunk 813/137585 to the database
# Added chunk 814/137585 to the database
# Added chunk 815/137585 to the database
# Added chunk 816/137585 to the database
# Added chunk 817/137585 to the database
# Added chunk 818/137585 to the database
# Added chunk 819/137585 to the database
# Added chunk 820/137585 to the database
# Added chunk 821/137585 to the database
# Added chunk 822/137585 to the database
# Added chunk 823/137585 to the database
# Added chunk 824/137585 to the database
# Added chunk 825/137585 to the database
# Added chunk 826/137585 to the database
# Added chunk 827/137585 to the database
# Added chunk 828/137585 to the database
# Added chunk 829/137585 to the database
# Added chunk 830/137585 to the database
# Added chunk 831/137585 to the database
# Added chunk 832/137585 to the database
# Added chunk 833/137585 to the database
# Added chunk 834/137585 to the database
# Added chunk 835/137585 to the database
# Added chunk 836/137585 to the database
# Added chunk 837/137585 to the database
# Added chunk 838/137585 to the database
# Added chunk 839/137585 to the database
# Added chunk 840/137585 to the database
# Added chunk 841/137585 to the database
# Added chunk 842/137585 to the database
# Added chunk 843/137585 to the database
# Added chunk 844/137585 to the database
# Added chunk 845/137585 to the database
# Added chunk 846/137585 to the database
# Added chunk 847/137585 to the database
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 34
#      32 #%% process data
#      33 for i, chunk in enumerate(dataset):
# ---> 34   add_chunk_to_database(chunk)
#      35   print(f'Added chunk {i+1}/{len(dataset)} to the database')
#
# Cell In[2], line 12, in add_chunk_to_database(chunk)
#      11 def add_chunk_to_database(chunk):
# ---> 12   embedding = ollama.embed(model=EMBEDDING_MODEL, input=chunk)['embeddings'][0]
#      13   VECTOR_DB.append((chunk, embedding))
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\ollama\_client.py:357, in Client.embed(self, model, input, truncate, options, keep_alive)
#     349 def embed(
#     350   self,
#     351   model: str = '',
#    (...)
#     355   keep_alive: Optional[Union[float, str]] = None,
#     356 ) -> EmbedResponse:
# --> 357   return self._request(
#     358     EmbedResponse,
#     359     'POST',
#     360     '/api/embed',
#     361     json=EmbedRequest(
#     362       model=model,
#     363       input=input,
#     364       truncate=truncate,
#     365       options=options,
#     366       keep_alive=keep_alive,
#     367     ).model_dump(exclude_none=True),
#     368   )
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\ollama\_client.py:178, in Client._request(self, cls, stream, *args, **kwargs)
#     174         yield cls(**part)
#     176   return inner()
# --> 178 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\ollama\_client.py:118, in Client._request_raw(self, *args, **kwargs)
#     116 def _request_raw(self, *args, **kwargs):
#     117   try:
# --> 118     r = self._client.request(*args, **kwargs)
#     119     r.raise_for_status()
#     120     return r
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\httpx\_client.py:827, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812     warnings.warn(message, DeprecationWarning)
#     814 request = self.build_request(
#     815     method=method,
#     816     url=url,
#    (...)
#     825     extensions=extensions,
#     826 )
# --> 827 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\httpx\_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\httpcore\_sync\connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\httpcore\_sync\connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\httpcore\_sync\http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\httpcore\_sync\http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\httpcore\_sync\http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\httpcore\_sync\http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
#%% save the   enumerated database
import pickle
  
def save_vector_db(filename='vector_db.pkl'):
    with open(filename, 'wb') as file:
        pickle.dump(VECTOR_DB, file)
    print(f"VECTOR_DB saved to {filename}")
    
def load_vector_db(filename='vector_db.pkl'):
    global VECTOR_DB
    with open(filename, 'rb') as file:
        VECTOR_DB = pickle.load(file)
    print(f"VECTOR_DB loaded from {filename}")

# Example call to load

#load_vector_db("EviewsInfo.pkl")    

# Example call to save
save_vector_db("EviewsInfo.pkl")
# Out:
# VECTOR_DB saved to EviewsInfo.pkl

# %%
  
 #%% Do the magic
  
input_query = input('Ask me a question: ')
retrieved_knowledge = retrieve(input_query)

print('Retrieved knowledge:')
for chunk, similarity in retrieved_knowledge:
  print(f' - (similarity: {similarity:.2f}) {chunk}')

instruction_prompt = f'''You are a helpful chatbot specializing in EViews programming.
Use only the following pieces of context to answer the question. Prioritize this information and do not make up any new information:
{'\n'.join([f' - {chunk}' for chunk, similarity in retrieved_knowledge])}
'''
#instruction_prompt = f'''You are a helpful chatbot.
#Use only the following pieces of context to answer the question. Don't make up any new information:
#{'\n'.join([f' - {chunk}' for chunk, similarity in retrieved_knowledge])}
#'''

stream = ollama.chat(
  model=LANGUAGE_MODEL,
  messages=[
    {'role': 'system', 'content': instruction_prompt},
    {'role': 'user', 'content': input_query},
  ],
  stream=True,
)

# print the response from the chatbot in real-time
print('Chatbot response:')
for chunk in stream:
  print(chunk['message']['content'], end='', flush=True)
# Out:
# Ask me a question:  Using the EViews econeometric language write a loop of a string containing the series variables x y z and create a new series variable called sum which is equal to teh three variables added together.  Only use EViews commands do not use python c or any opther programming language
# Retrieved knowledge:
#  - (similarity: 0.53) =
#  - (similarity: 0.53) =
#  - (similarity: 0.53) =
# Chatbot response:
# Here is an EViews command that creates a loop, adds the three series variables, and then calculates a new series variable as their sum:
#
# ```
# loop (x = x, y = y, z = z)
# sum(x + y + z) := x + y + z
# end;
# ```
#
# This command defines a loop with named iterations for `x`, `y`, and `z`. Inside the loop, it calculates the sum of the three variables using the arithmetic operators `+` and stores the result in `sum(x + y + z)`.
#
# Note that this command assumes that you are running EViews version 8 or earlier. In later versions, you can use `SUM(x + y + z) := x + y + z;` instead of looping over these commands.

# %%
print(VECTOR_DB[1])
# Out:
# ('p', [-0.010467437, 0.042489957, -0.036645785, 0.01405966, 0.014432011, 0.05906182, -0.0004181107, -0.016029326, -0.016258057, -0.07520244, -0.022527006, -0.044600144, -0.07355539, -0.015139903, 0.0061415923, 0.041846853, 0.041392505, 0.017007584, 0.018186258, -0.011615888, 0.041572433, 0.041390106, 0.023189226, -0.005749395, -0.020055238, 0.016592171, 0.052495293, 0.009966589, -0.016487319, -0.049995262, 0.0056141666, 0.01603666, 0.013888949, -0.00088530476, 0.016068432, -0.005997243, 0.030630913, 0.008960432, -0.008777918, 0.033743437, -0.032206982, -0.0007177639, -0.005882533, -0.028848322, -0.037640207, -0.006902742, -0.0010164713, 0.06386116, -0.040799152, 0.009652419, -0.066942155, 0.022128345, -0.004309547, 0.0010704304, -0.017608603, -0.0108743375, -0.021685157, -0.047673795, 0.023201082, -0.017969409, -0.006947705, 0.033698373, 0.024187202, -0.029984074, 0.039681092, -0.037730284, -0.021764707, 0.04118818, -0.020240434, -0.0027808927, -0.03371502, -0.016884841, 0.0066822926, -0.04919319, 0.04825454, -0.024644122, 0.0013281436, 0.052336354, 0.0006561365, 0.06500877, 0.078365415, 0.