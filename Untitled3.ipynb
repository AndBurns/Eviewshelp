# %%
"""
Author: Andrew Burns
Created Date: March 2, 2025
Updated Date: March 7, 2025
"""
from pathlib import Path
from lxml import html
from lxml.html.clean import clean_html
import time
import re

dataset = []
executed_files = []  # List to store executed file names
skipped_files = []   # List to store skipped file names
first_match = True

# Set to track previously processed lines
processed_lines = set()

# Directory containing the HTML files
directory = Path(r'C:\git\eviewshelp\PRG')

# Loop through all .html files in the directory
for html_file in directory.glob('*.PRG'):    
    # Skip files with 'snapshot' in their names
    if 'snapshot' in html_file.name.lower():
        skipped_files.append(html_file.name)  # Add to skipped list
        print(f"Skipped file: {html_file.name} (Contains 'snapshot')")
        continue  # Skip to the next iteration
    
    # Check if the filename ends with 5 digits and 'SOLVE.PRG'
    if re.match(r'.*\d{5}Solve.prg$', html_file.name):
        if first_match:
            with open(html_file, 'r', encoding='ISO-8859-1') as file:
                content = file.readlines()  # Read file line by line
            print(f"Read file: {html_file.name}")
            print(f'Loaded {len(content)} entries')
            
            # Process each line in the file
            for line in content:
                if line not in processed_lines:
                    dataset.append(line)  # Add to dataset
                    processed_lines.add(line)     # Mark this line as processed
            
            executed_files.append(html_file.name)  # Add to executed list
            first_match = False  # After the first match, set to False
        else:
            skipped_files.append(html_file.name)  # Add to skipped list
            print(f"Skipped file: {html_file.name}")
    else:
        with open(html_file, 'r', encoding='ISO-8859-1') as file:
            content = file.readlines()  # Read file line by line
        print(f"Read file: {html_file.name}")
        print(f'Loaded {len(content)} entries')
        
        # Process each line in the file
        for line in content:
            if line not in processed_lines:
                dataset.append(line)  # Add to dataset
                processed_lines.add(line)     # Mark this line as processed
        
        executed_files.append(html_file.name)  # Add to executed list
# Out:
# Read file: _2022_08_build_02_readdata.prg_02_readdata.prg
# Loaded 279 entries
# Read file: _2022_08_build_03_equations.prg_03_equations.prg
# Loaded 563 entries
# Read file: _2022_08_build_04_solve.prg_04_solve.prg
# Loaded 78 entries
# Read file: _2022_08_build_05_interface.prg_05_interface.prg
# Loaded 43 entries
# Read file: _2022_08_build_99_convergence.prg_99_convergence.prg
# Loaded 165 entries
# Read file: _2022_08_build_99_IRF.prg_99_IRF.prg
# Loaded 310 entries
# Read file: _2022_08_build_extend_forecast.prg_extend_forecast.prg
# Loaded 105 entries
# Read file: _2022_08_master.prg_master.prg
# Loaded 116 entries
# Skipped file: _2022_08_master.prg_Snapshots_snapshot_lastsave.prg_snapshot_lastsave.prg (Contains 'snapshot')
# Read file: _2022_08_training_programs_build_02_readdata.prg_02_readdata.prg
# Loaded 278 entries
# Read file: _2022_08_training_programs_build_03_equations.prg_03_equations.prg
# Loaded 520 entries
# Read file: _2022_08_training_programs_build_04_solve.prg_04_solve.prg
# Loaded 175 entries
# Read file: _2022_08_training_programs_build_05_interface.prg_05_interface.prg
# Loaded 43 entries
# Read file: _2022_08_training_programs_build_99_convergence.prg_99_convergence.prg
# Loaded 165 entries
# Read file: _2022_08_training_programs_build_99_IRF.prg_99_IRF.prg
# Loaded 310 entries
# Read file: _2022_08_training_programs_build_extend_forecast.prg_extend_forecast.prg
# Loaded 105 entries
# Read file: _2022_08_training_programs_master.prg_master.prg
# Loaded 86 entries
# Read file: _2022_12_build_02_readdata.prg_02_readdata.prg
# Loaded 296 entries
# Skipped file: _2022_12_build_02_readdata.prg_Snapshots_snapshot_lastsave.prg_snapshot_lastsave.prg (Contains 'snapshot')
# Read file: _2022_12_build_031_enerdat.prg_031_enerdat.prg
# Loaded 791 entries
# Skipped file: _2022_12_build_031_enerdat.prg_Snapshots_snapshot_lastsave.prg_snapshot_lastsave.prg (Contains 'snapshot')
# Read file: _2022_12_build_032_damagedat.prg_032_damagedat.prg
# Loaded 171 entries
# Read file: _2022_12_build_033_naturalcap.prg_033_naturalcap.prg
# Loaded 127 entries
# Read file: _2022_12_build_03_equations.prg_03_equations.prg
# Loaded 596 entries
# Skipped file: _2022_12_build_03_equations.prg_Snapshots_snapshot_lastsave.prg_snapshot_lastsave.prg (Contains 'snapshot')
# Read file: _2022_12_build_04_solve.prg_04_solve.prg
# Loaded 236 entries
# Skipped file: _2022_12_build_04_solve.prg_Snapshots_snapshot_lastsave.prg_snapshot_lastsave.prg (Contains 'snapshot')
# Read file: _2022_12_build_05_interface.prg_05_interface.prg
# Loaded 43 entries
# Skipped file: _2022_12_build_05_interface.prg_Snapshots_snapshot_lastsave.prg_snapshot_lastsave.prg (Contains 'snapshot')
# Read file: _2022_12_build_99_convergence.prg_99_convergence.prg
# Loaded 254 entries
# Skipped file: _2022_12_build_99_convergence.prg_Snapshots_snapshot_lastsave.prg_snapshot_lastsave.prg (Contains 'snapshot')
# Read file: _2022_12_build_99_IRF.prg_99_IRF.prg
# Loaded 310 entries
# Read file: _2022_12_build_Backup_02_readdata.prg_02_readdata.prg
# Loaded 292 entries
# Read file: _2022_12_build_Backup_031_enerdat.prg_031_enerdat.prg
# Loaded 748 entries
# Read file: _2022_12_build_Backup_032_damagedat.prg_032_damagedat.prg
# Loaded 171 entries
# Read file: _2022_12_build_Backup_033_naturalcap.prg_033_naturalcap.prg
# Loaded 127 entries
# Read file: _2022_12_build_Backup_03_equations.prg_03_equations.prg
# Loaded 565 entries
# Read file: _2022_12_build_Backup_04_solve.prg_04_solve.prg
# Loaded 234 entries
# Read file: _2022_12_build_Backup_05_interface.prg_05_interface.prg
# Loaded 43 entries
# Read file: _2022_12_build_Backup_99_convergence.prg_99_convergence.prg
# Loaded 234 entries
# Read file: _2022_12_build_Backup_99_IRF.prg_99_IRF.prg
# Loaded 310 entries
# Read file: _2022_12_build_Backup_extend_forecast.prg_extend_forecast.prg
# Loaded 105 entries
# Read file: _2022_12_build_Backup_shocks.prg_shocks.prg
# Loaded 559 entries
# Read file: _2022_12_build_Backup_systemsest.prg_systemsest.prg
# Loaded 32 entries
# Read file: _2022_12_build_damagenew.prg_damagenew.prg
# Loaded 172 entries
# Skipped file: _2022_12_build_damagenew.prg_Snapshots_snapshot_lastsave.prg_snapshot_lastsave.prg (Contains 'snapshot')
# Read file: _2022_12_build_extend_forecast.prg_extend_forecast.prg
# Loaded 105 entries
# Read file: _2022_12_build_shocks.prg_shocks.prg
# Loaded 563 entries
# Skipped file: _2022_12_build_shocks.prg_Snapshots_snapshot_lastsave.prg_snapshot_lastsave.prg (Contains 'snapshot')
# Skipped file: _2022_12_build_systemsest.prg_Snapshots_snapshot_lastsave.prg_snapshot_lastsave.prg (Contains 'snapshot')
# Read file: _2022_12_build_systemsest.prg_systemsest.prg
# Loaded 32 entries
# Read file: _2022_12_exogforecastsplice.prg_exogforecastsplice.prg
# Loaded 242 entries
# Read file: _2022_12_fixexports.prg_fixexports.prg
# Loaded 13 entries
# Read file: _2022_12_master.prg_master.prg
# Loaded 229 entries
# Skipped file: _2022_12_master.prg_Snapshots_snapshot_20221206_143104_auto.prg_snapshot_20221206_143104_auto.prg (Contains 'snapshot')
# Skipped file: _2022_12_master.prg_Snapshots_snapshot_lastsave.prg_snapshot_lastsave.prg (Contains 'snapshot')
# Read file: _
solve.prg
# Skipped file: _2024_BGD_Programs_BGD00084Solve.prg_BGD00084Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00085Solve.prg_BGD00085Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00086Solve.prg_BGD00086Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00087Solve.prg_BGD00087Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00088Solve.prg_BGD00088Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00089Solve.prg_BGD00089Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00090Solve.prg_BGD00090Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00091Solve.prg_BGD00091Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00092Solve.prg_BGD00092Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00093Solve.prg_BGD00093Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00094Solve.prg_BGD00094Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00095Solve.prg_BGD00095Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00096Solve.prg_BGD00096Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00097Solve.prg_BGD00097Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00098Solve.prg_BGD00098Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00099Solve.prg_BGD00099Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00100Solve.prg_BGD00100Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00101Solve.prg_BGD00101Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00102Solve.prg_BGD00102Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00103Solve.prg_BGD00103Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00104Solve.prg_BGD00104Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00105Solve.prg_BGD00105Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00106Solve.prg_BGD00106Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00107Solve.prg_BGD00107Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00108Solve.prg_BGD00108Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00109Solve.prg_BGD00109Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00110Solve.prg_BGD00110Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00111Solve.prg_BGD00111Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00112Solve.prg_BGD00112Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00113Solve.prg_BGD00113Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00114Solve.prg_BGD00114Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00115Solve.prg_BGD00115Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00116Solve.prg_BGD00116Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00117Solve.prg_BGD00117Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00118Solve.prg_BGD00118Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00119Solve.prg_BGD00119Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00120Solve.prg_BGD00120Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00121Solve.prg_BGD00121Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00122Solve.prg_BGD00122Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00123Solve.prg_BGD00123Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00124Solve.prg_BGD00124Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00125Solve.prg_BGD00125Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00126Solve.prg_BGD00126Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00127Solve.prg_BGD00127Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00128Solve.prg_BGD00128Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00129Solve.prg_BGD00129Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00130Solve.prg_BGD00130Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00131Solve.prg_BGD00131Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00132Solve.prg_BGD00132Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00133Solve.prg_BGD00133Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00134Solve.prg_BGD00134Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00135Solve.prg_BGD00135Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00136Solve.prg_BGD00136Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00137Solve.prg_BGD00137Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00138Solve.prg_BGD00138Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00139Solve.prg_BGD00139Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00140Solve.prg_BGD00140Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00141Solve.prg_BGD00141Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00142Solve.prg_BGD00142Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00143Solve.prg_BGD00143Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00144Solve.prg_BGD00144Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00145Solve.prg_BGD00145Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00146Solve.prg_BGD00146Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00147Solve.prg_BGD00147Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00148Solve.prg_BGD00148Solve.prg
# Skipped file: _2024_BGD_Programs_BGD00149Solve.prg_BGD00149Solve.prg
# Read file: _2024_BGD_Programs_CalcFitted.prg_CalcFitted.prg
# Loaded 43 entries
# Read file: _2024_BGD_Programs_Convert_2_to_0.prg_Convert_2_to_0.prg
# Loaded 68 entries
# Read file: _2024_BGD_shocks.prg_shocks.prg
# Loaded 172 entries
# Skipped file: _2024_BGD_shocks.prg_Snapshots_snapshot_lastsave.prg_snapshot_lastsave.prg (Contains 'snapshot')
# Skipped file: _2024_BGD_spliceforecasts.prg_Snapshots_snapshot_lastsave.prg_snapshot_lastsave.prg (Contains 'snapshot')
# Read file: _2024_BGD_SpliceForecasts.prg_SpliceForecasts.prg
# Loaded 75 entries
# Read file: _build_02_readdata.prg_02_readdata.prg
# Loaded 279 entries
# Read file: _build_03_equations.prg_03_equations.prg
# Loaded 563 entries
# Read file: _build_04_solve.prg_04_solve.prg
# Loaded 184 entries
# Read file: _build_05_interface.prg_05_interface.prg
# Loaded 43 entries
# Read file: _build_99_convergence.prg_99_convergence.prg
# Loaded 165 entries
# Read file: _build_99_IRF.prg_99_IRF.prg
# Loaded 310 entries
# Read file: _build_extend_forecast.prg_extend_forecast.prg
# Loaded 105 entries
# Read file: _master.prg_master.prg
# Loaded 89 entries
# Read file: _training_programs_build_02_readdata.prg_02_readdata.prg
# Loaded 278 entries
# Read file: _training_programs_build_03_equations.prg_03_equations.prg
# Loaded 520 entries
# Read file: _training_programs_build_04_solve.prg_04_solve.prg
# Loaded 175 entries
# Read file: _training_programs_build_05_interface.prg_05_interface.prg
# Loaded 43 entries
# Read file: _training_programs_build_99_convergence.prg_99_convergence.prg
# Loaded 165 entries
# Read file: _training_programs_build_99_IRF.prg_99_IRF.prg
# Loaded 310 entries
# Read file: _training_programs_build_extend_forecast.prg_extend_forecast.prg
# Loaded 105 entries
# Read file: _training_programs_master.prg_master.prg
# Loaded 86 entries

# %%
#%% Begin program
import ollama

EMBEDDING_MODEL = 'hf.co/CompendiumLabs/bge-base-en-v1.5-gguf'
LANGUAGE_MODEL = 'hf.co/bartowski/Llama-3.2-1B-Instruct-GGUF'

# Each element in the VECTOR_DB will be a tuple (chunk, embedding)
# The embedding is a list of floats, for example: [0.1, 0.04, -0.34, 0.21, ...]
VECTOR_DB = []

#%% routines
def add_chunk_to_database(chunk):
  embedding = ollama.embed(model=EMBEDDING_MODEL, input=chunk)['embeddings'][0]
  VECTOR_DB.append((chunk, embedding))
  
def cosine_similarity(a, b):
  dot_product = sum([x * y for x, y in zip(a, b)])
  norm_a = sum([x ** 2 for x in a]) ** 0.5
  norm_b = sum([x ** 2 for x in b]) ** 0.5
  return dot_product / (norm_a * norm_b)

def retrieve(query, top_n=3):
  query_embedding = ollama.embed(model=EMBEDDING_MODEL, input=query)['embeddings'][0]
  # temporary list to store (chunk, similarity) pairs
  similarities = []
  for chunk, embedding in VECTOR_DB:
    similarity = cosine_similarity(query_embedding, embedding)
    similarities.append((chunk, similarity))
  # sort by similarity in descending order, because higher similarity means more relevant chunks
  similarities.sort(key=lambda x: x[1], reverse=True)
  # finally, return the top N most relevant chunks
  return similarities[:top_n]

# %%
#%% process data
start_time = time.time()
for i, chunk in enumerate(dataset):
  add_chunk_to_database(chunk)
  if (i % 100)==0 :
      print(f'Added chunk {i}/{len(dataset)} to the database, {100*i/len(dataset):.2f} complete')# Elapsed time: {int(elapsed_minutes)}m {int(elapsed_seconds)}s')

#%% save the enumerated database
import pickle
  
def save_vector_db(filename='vector_db.pkl'):
    with open(filename, 'wb') as file:
        pickle.dump(VECTOR_DB, file)
    print(f"VECTOR_DB saved to {filename}")
    
def load_vector_db(filename='vector_db.pkl'):
    global VECTOR_DB
    with open(filename, 'rb') as file:
        VECTOR_DB = pickle.load(file)
    print(f"VECTOR_DB loaded from {filename}")

# Example call to load
# load_vector_db("EviewsPRG.pkl")    

# Example call to save
save_vector_db("Eviewsprg.pkl")
#print(Total read time:
# Out:
# Added chunk 0/3915 to the database, 0.00 complete
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[9], line 4
#       2 start_time = time.time()
#       3 for i, chunk in enumerate(dataset):
# ----> 4   add_chunk_to_database(chunk)
#       5   if (i % 100)==0 :
#       6       print(f'Added chunk {i}/{len(dataset)} to the database, {100*i/len(dataset):.2f} complete')# Elapsed time: {int(elapsed_minutes)}m {int(elapsed_seconds)}s')
#
# Cell In[8], line 13, in add_chunk_to_database(chunk)
#      12 def add_chunk_to_database(chunk):
# ---> 13   embedding = ollama.embed(model=EMBEDDING_MODEL, input=chunk)['embeddings'][0]
#      14   VECTOR_DB.append((chunk, embedding))
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\ollama\_client.py:357, in Client.embed(self, model, input, truncate, options, keep_alive)
#     349 def embed(
#     350   self,
#     351   model: str = '',
#    (...)
#     355   keep_alive: Optional[Union[float, str]] = None,
#     356 ) -> EmbedResponse:
# --> 357   return self._request(
#     358     EmbedResponse,
#     359     'POST',
#     360     '/api/embed',
#     361     json=EmbedRequest(
#     362       model=model,
#     363       input=input,
#     364       truncate=truncate,
#     365       options=options,
#     366       keep_alive=keep_alive,
#     367     ).model_dump(exclude_none=True),
#     368   )
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\ollama\_client.py:178, in Client._request(self, cls, stream, *args, **kwargs)
#     174         yield cls(**part)
#     176   return inner()
# --> 178 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\ollama\_client.py:122, in Client._request_raw(self, *args, **kwargs)
#     120   return r
#     121 except httpx.HTTPStatusError as e:
# --> 122   raise ResponseError(e.response.text, e.response.status_code) from None
#     123 except httpx.ConnectError:
#     124   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: {} (status code: 500)

# %%
#%% Do the magic
input_query = input('Ask me a question: ')
retrieved_knowledge = retrieve(input_query)

print('Retrieved knowledge:')
for chunk, similarity in retrieved_knowledge:
  print(f' - (similarity: {similarity:.2f}) {chunk}')

instruction_prompt = f'''You are a helpful chatbot.
Use only the following pieces of context to answer the question. Don't give answers based on programming languages other than EViews. Don't make up any new information:
{'\n'.join([f' - {chunk}' for chunk, similarity in retrieved_knowledge])}
'''

stream = ollama.chat(
  model=LANGUAGE_MODEL,
  messages=[
    {'role': 'system', 'content': instruction_prompt},
    {'role': 'user', 'content': input_query},
  ],
  stream=True,
)

# print the response from the chatbot in real-time
print('Chatbot response:')
for chunk in stream:
  print(chunk['message']['content'], end='', flush=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 #%% Do the magic
# ----> 2 input_query = input('Ask me a question: ')
#       3 retrieved_knowledge = retrieve(input_query)
#       5 print('Retrieved knowledge:')
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\AppData\Local\anaconda3\envs\evhelp\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
# Ask me a question:  How many flowers in a bunch?
